# %%
import pandas as pd

# %%
df11 = pd.read_csv('heart.csv',sep='\t')

# %%
df11
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for i in df:
    sns.boxplot(df[i])
    plt.show()

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
sns.boxplot(df['sex'],df['chol'])

# %% [raw]
# #chol range is more in females than males

# %%
sns.boxplot(df['cp'],df['thalach'],hue=df['sex'])

# %%
sns.scatterplot(df['age'],df['chol'])

# %%
sns.lmplot(x='age',y='chol',hue='sex',col='cp',data=df)

# %%
# Statistical model

# %%
import statsmodels.api as sm

# %%
x = df11.drop(columns='target')
y = df11['target']

# %%
x_const = sm.add_constant(x)
# Out:
# /Users/zameershaik/Applications/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
statmodel = sm.Logit(y,x_const).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.348904
#          Iterations 7

# %%
statmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                 target   No. Observations:                  303
# Model:                          Logit   Df Residuals:                      289
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 24 Feb 2020   Pseudo R-squ.:                  0.4937
# Time:                        10:29:54   Log-Likelihood:                -105.72
# converged:                       True   LL-Null:                       -208.82
# Covariance Type:            nonrobust   LLR p-value:                 7.262e-37
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.4505      2.571      1.342      0.180      -1.590       8.490
# age           -0.0049      0.023     -0.212      0.832      -0.050       0.041
# ...

# %%
# logistic reg

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.3,random_state=420)

# %%
lr.fit(x_train,y_train)
# Out:
# /Users/zameershaik/Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.metrics import accuracy_score,classification_report,roc_auc_score,roc_curve,confusion_matrix

# %%
ytrain_pred = lr.predict(x_train)
ytrain_prob= lr.predict_proba(x_train)[:,1]

# %%
accuracy_score(y_train,ytrain_pred)
# Out:
# 0.8962264150943396

# %%
print(classification_report(y_train,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87        91
#            1       0.88      0.95      0.91       121
#
#     accuracy                           0.90       212
#    macro avg       0.90      0.89      0.89       212
# weighted avg       0.90      0.90      0.90       212

# %%
confusion_matrix(y_train,ytrain_pred)
# Out:
# array([[ 75,  16],
#        [  6, 115]])

# %%
roc_auc_score(y_train,ytrain_prob)
# Out:
# 0.9544092271364999

# %%
fpr,tpr,tresh =roc_curve(y_train,ytrain_prob)

# %%
tresh[0] = tresh[0] - 1

# %%
plt.plot(fpr,fpr)
plt.plot(fpr,tpr)
plt.plot(fpr,tresh)

# %%
ytest_pred = lr.predict(x_test)
ytest_prob = lr.predict_proba(x_test)[:,1]

# %%
accuracy_score(y_test,ytest_pred)
# Out:
# 0.7692307692307693

# %%
roc_auc_score(y_test,ytest_prob)
# Out:
# 0.8249516441005803

# %%
df1 = sns.load_dataset('iris')

# %%
df1['species'].value_counts()
# Out:
# A    50
# C    50
# B    50
# Name: species, dtype: int64

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import Pipeline

# %%
pl = Pipeline([
        #('vec', CountVectorizer(token_pattern = tks)),
        ('clf', OneVsRestClassifier(LogisticRegression()))
    ])

# %%
df1.replace({'A':1,'B':3,'C':2},inplace=True)

# %%
x1 = df1.drop(columns='species')
y1 = df1['species']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df1['species'] = pd.to_numeric(df1['species'],errors='ignore')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 5.9 KB

# %%
pl.fit(x,y)
# Out:
# Pipeline(memory=None,
#          steps=[('clf',
#                  OneVsRestClassifier(estimator=LogisticRegression(C=1.0,
#                                                                   class_weight=None,
#                                                                   dual=False,
#                                                                   fit_intercept=True,
#                                                                   intercept_scaling=1,
#                                                                   l1_ratio=None,
#                                                                   max_iter=100,
#                                                                   multi_class='auto',
#                                                                   n_jobs=None,
#                                                                   penalty='l2',
#                                                                   random_state=None,
# ...

# %%
pl.predict_proba(x)
# Out:
# array([[8.96807569e-01, 1.03191359e-01, 1.07219602e-06],
#        [7.78979389e-01, 2.21019299e-01, 1.31168933e-06],
#        [8.34864184e-01, 1.65134802e-01, 1.01485082e-06],
#        [7.90001986e-01, 2.09996107e-01, 1.90723705e-06],
#        [9.12050403e-01, 8.79485212e-02, 1.07537143e-06],
#        [9.53753848e-01, 4.62428811e-02, 3.27143574e-06],
#        [8.81758997e-01, 1.18239283e-01, 1.72030712e-06],
#        [8.69394053e-01, 1.30604413e-01, 1.53360450e-06],
#        [7.41444403e-01, 2.58554001e-01, 1.59626610e-06],
#        [7.80754800e-01, 2.19243884e-01, 1.31611039e-06],
#        [9.26219998e-01, 7.37788077e-02, 1.19400563e-06],
#        [8.58526062e-01, 1.41471734e-01, 2.20392291e-06],
#        [7.61298678e-01, 2.38700278e-01, 1.04402663e-06],
#        [7.78325486e-01, 2.21673981e-01, 5.33237499e-07],
#        [9.68068726e-01, 3.19308983e-02, 3.75299274e-07],
#        [9.86161018e-01, 1.38377099e-02, 1.27223177e-06],
# ...

# %%
a = pd.DataFrame(pl.predict(x))

# %%
a[0].value_counts()
# Out:
# virginica     53
# setosa        50
# versicolor    47
# Name: 0, dtype: int64

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = [variance_inflation_factor(x_const.values, i) for i in range(x_const.shape[1])]
pd.DataFrame({'vif': vif[1:]}, index=x.columns).T
# Out:
#           age       sex        cp  trestbps      chol       fbs   restecg  \
# vif  1.443474  1.161866  1.284456  1.170591  1.150174  1.087379  1.060998
#
#       thalach     exang   oldpeak     slope       ca      thal
# vif  1.613726  1.402001  1.705857  1.642595  1.20257  1.147279

# %%
pl.predict_proba(x1)
# Out:
# array([[8.96807569e-01, 1.03191359e-01, 1.07219602e-06],
#        [7.78979389e-01, 2.21019299e-01, 1.31168933e-06],
#        [8.34864184e-01, 1.65134802e-01, 1.01485082e-06],
#        [7.90001986e-01, 2.09996107e-01, 1.90723705e-06],
#        [9.12050403e-01, 8.79485212e-02, 1.07537143e-06],
#        [9.53753848e-01, 4.62428811e-02, 3.27143574e-06],
#        [8.81758997e-01, 1.18239283e-01, 1.72030712e-06],
#        [8.69394053e-01, 1.30604413e-01, 1.53360450e-06],
#        [7.41444403e-01, 2.58554001e-01, 1.59626610e-06],
#        [7.80754800e-01, 2.19243884e-01, 1.31611039e-06],
#        [9.26219998e-01, 7.37788077e-02, 1.19400563e-06],
#        [8.58526062e-01, 1.41471734e-01, 2.20392291e-06],
#        [7.61298678e-01, 2.38700278e-01, 1.04402663e-06],
#        [7.78325486e-01, 2.21673981e-01, 5.33237499e-07],
#        [9.68068726e-01, 3.19308983e-02, 3.75299274e-07],
#        [9.86161018e-01, 1.38377099e-02, 1.27223177e-06],
# ...

# %%
y1pred = pl.predict(x1)

# %%
y1prob = pl.predict_proba(x1)[:,1]

# %%
accuracy_score(y1,y1pred)
# Out:
# 0.9533333333333334

# %%
confusion_matrix(y1,y1pred)
# Out:
# array([[50,  0,  0],
#        [ 0, 45,  5],
#        [ 0,  2, 48]])

# %%
df11
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
y_test
# Out:
# 203    0
# 269    0
# 198    0
# 80     1
# 233    0
# 292    0
# 56     1
# 155    1
# 284    0
# 300    0
# 34     1
# 218    0
# 49     1
# 264    0
# 267    0
# 177    0
# 7      1
# 19     1
# 199    0
# 193    0
# 116    1
# 276    0
# 282    0
# 219    0
# 180    0
# 178    0
# 130    1
# 245    0
# 0      1
# 150    1
#       ..
# 124    1
# 114    1
# 25     1
# 184    0
# 270    0
# 302    0
# 293    0
# 55     1
# 298    0
# 153    1
# 6      1
# 222    0
# 171    0
# 110    1
# 135    1
# 183    0
# 84     1
# 202    0
# 17     1
# 234    0
# 123    1
# 32     1
# 120    1
# 162    1
# 119    1
# 253    0
# 44     1
# 101    1
# 235    0
# 229    0
# Name: target, Length: 91, dtype: int64

# %%
y_train
# Out:
# 64     1
# 227    0
# 127    1
# 69     1
# 148    1
# 39     1
# 279    0
# 122    1
# 77     1
# 117    1
# 179    0
# 239    0
# 78     1
# 240    0
# 20     1
# 113    1
# 33     1
# 87     1
# 134    1
# 156    1
# 144    1
# 189    0
# 278    0
# 161    1
# 90     1
# 137    1
# 263    0
# 244    0
# 275    0
# 62     1
#       ..
# 136    1
# 23     1
# 28     1
# 191    0
# 246    0
# 5      1
# 59     1
# 107    1
# 31     1
# 76     1
# 47     1
# 197    0
# 37     1
# 221    0
# 205    0
# 182    0
# 132    1
# 152    1
# 212    0
# 230    0
# 142    1
# 151    1
# 126    1
# 266    0
# 154    1
# 185    0
# 115    1
# 287    0
# 63     1
# 72     1
# Name: target, Length: 212, dtype: int64

# %%
df11
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dc = DecisionTreeClassifier()

# %%
dc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
ytrain_pred = dc.predict(x_train)

# %%
ytrain_prob = dc.predict_proba(x_train)[:,1]

# %%
accuracy_score(y_train,ytrain_pred)
# Out:
# 1.0

# %%
ytest_pred = dc.predict(x_test)
ytrain_prob = dc.predict_proba(x_test)[:,1]

# %%
accuracy_score(y_test,ytest_pred)
# Out:
# 0.7142857142857143

# %%
# Hyper paramater tuning

# %%
import scipy.stats as st
from sklearn.model_selection import RandomizedSearchCV

# %%
paramns = {
    'criterion':['gini','entropy'],
    'splitter':['best','random'],
    'max_depth':st.randint(1,30),
    'min_samples_split':st.randint(1,100),
    'min_samples_leaf':st.randint(1,100)
}

# %%
rv = RandomizedSearchCV(dc,param_distributions=paramns,n_iter=50,n_jobs=-1,cv=5)

# %%
rv.fit(x,y)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features=None,
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     presort='deprecated',
# ...

# %%
rv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 13,
#  'min_samples_leaf': 18,
#  'min_samples_split': 15,
#  'splitter': 'best'}

# %%
dtc = DecisionTreeClassifier(**rv.best_params_)

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=13, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=18, min_samples_split=15,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
ytrain_pred = dtc.predict(x_train)

# %%
ytrain_prob = dtc.predict_proba(x_train)[:,1]

# %%
accuracy_score(y_train,ytrain_pred)
# Out:
# 0.8632075471698113

# %%
ytest_pred = dtc.predict(x_test)
ytest_prob = dtc.predict_proba(x_test)[:,1]

# %%
accuracy_score(y_test,ytest_pred)
# Out:
# 0.7032967032967034

# %%
# Voting Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.ensemble import VotingClassifier

# %%
lr = LogisticRegression()
dc = DecisionTreeClassifier()
rf = RandomForestClassifier()
knn = KNeighborsClassifier(5)

# %%
est ={
    'lr':lr,
    'dc':dc,
    'rf':rf,
    'knn':knn
}

# %%
vc = VotingClassifier(estimators=(('lr',lr),('dc',dc),('rf',rf),('knn',knn)),voting='soft')

# %%
vc.fit(x_train,y_train)
# Out:
# /Users/zameershaik/Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# VotingClassifier(estimators=(('lr',
#                               LogisticRegression(C=1.0, class_weight=None,
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=100,
#                                                  multi_class='auto',
# ...

# %%
ytrain_pred = vc.predict(x_train)
ytrain_prob = vc.predict_proba(x_train)[:,1]

# %%
accuracy_score(y_train,ytrain_pred)
# Out:
# 0.9952830188679245

# %%
ytest_pred = vc.predict(x_test)
ytest_prob = vc.predict_proba(x_test)[:,1]

# %%
accuracy_score(y_test,ytest_pred)
# Out:
# 0.7472527472527473

# %%
paramnsf = {
    'n_estimators':st.randint(1,100),
    'criterion':['gini','entropy'],
    'max_depth':st.randint(1,15),
    'min_samples_split':st.randint(1,100),
    'min_samples_leaf':st.randint(1,100),
    
    'max_features':st.randint(1,10)
}

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
ytrain_pred = rfc.predict(x_train)
ytrain_prob = rfc.predict_proba(x_train)[:,1]

# %%
accuracy_score(y_train,ytrain_pred)
# Out:
# 1.0

# %%
ytest_pred = vc.predict(x_test)
ytest_prob = vc.predict_proba(x_test)[:,1]

# %%
accuracy_score(y_test,ytest_pred)
# Out:
# 0.7472527472527473

# %%
knn = KNeighborsClassifier().fit(x_train,y_train)

# %%
ytrain_pred = knn.predict(x_train)
ytrain_prob = knn.predict_proba(x_train)[:,1]

# %%
accuracy_score(y_train,ytrain_pred)
# Out:
# 0.75

# %%
ytest_pred = vc.predict(x_test)
ytest_prob = vc.predict_proba(x_test)[:,1]

# %%
accuracy_score(y_test,ytest_pred)
# Out:
# 0.7472527472527473

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
