# %%
import pandas as pd
import scipy.stats as st

# %%
patti = pd.read_csv('per_game_stats.csv')
tab = pd.crosstab(patti['Tm'],columns=[patti['Player']])
tab
# Out:
# Player  Kobe Bryant  Lebron James  Michael Jordan
# Tm
# CHI               0             0              26
# CLE               0            20               0
# LAL              35             1               0
# MIA               0             8               0
# WAS               0             0               2

# %%
patti
# Out:
#      Season  Age   Tm   Lg Pos   G  GS    MP    FG   FGA  ...  DRB   TRB  AST  \
# 0   2003-04   19  CLE  NBA  SG  79  79  39.5   7.9  18.9  ...  4.2   5.5  5.9
# 1   2004-05   20  CLE  NBA  SF  80  80  42.4   9.9  21.1  ...  6.0   7.4  7.2
# 2   2005-06   21  CLE  NBA  SF  79  79  42.5  11.1  23.1  ...  6.1   7.0  6.6
# 3   2006-07   22  CLE  NBA  SF  78  78  40.9   9.9  20.8  ...  5.7   6.7  6.0
# 4   2007-08   23  CLE  NBA  SF  75  74  40.4  10.6  21.9  ...  6.1   7.9  7.2
# 5   2008-09   24  CLE  NBA  SF  81  81  37.7   9.7  19.9  ...  6.3   7.6  7.2
# 6   2009-10   25  CLE  NBA  SF  76  76  39.0  10.1  20.1  ...  6.4   7.3  8.6
# 7   2010-11   26  MIA  NBA  SF  79  79  38.8   9.6  18.8  ...  6.5   7.5  7.0
# 8   2011-12   27  MIA  NBA  SF  62  62  37.5  10.0  18.9  ...  6.4   7.9  6.2
# 9   2012-13   28  MIA  NBA  PF  76  76  37.9  10.1  17.8  ...  6.8   8.0  7.3
# 10  2013-14   29  MIA  NBA  PF  77  77  37.7  10.0  17.6  ...  5.9   6.9  6.3
# ...

# %%
chi2_stat=st.chi2_contingency(tab)
a=chi2_stat[0]
a
# Out:
# 178.36015325670502

# %%
st.chi2.isf(0.05,df=8)
# Out:
# 15.507313055865454

# %%
st.chisquare(tab)
# Out:
# Power_divergenceResult(statistic=array([140.        ,  51.17241379,  93.42857143]), pvalue=array([2.82256931e-29, 2.05450836e-10, 2.45975536e-19]))
